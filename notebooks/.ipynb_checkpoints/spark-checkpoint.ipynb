# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("CSV to PG") \
    .config("spark.master", "spark://spark-master:7077") \
    .getOrCreate()

df = spark.read.option("header", True).csv("/home/jovyan/data/MOCK_DATA.csv")
df.show(5)
